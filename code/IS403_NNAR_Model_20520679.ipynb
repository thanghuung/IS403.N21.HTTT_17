# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error
from sklearn.metrics import PredictionErrorDisplay
from statsmodels.graphics.tsaplots import plot_pacf

# %% [markdown]
# <h2>1. Data ARE-Historical-Data-2015

# %%
# Import data
df = pd.read_csv('ARE-Historical-Data-2015.csv', index_col='Date', parse_dates=True)
df = df.iloc[::-1]
df1=df.reset_index()['Price']

# %%
# Kiểm tra sự tương quan một phần PAFC
plot_pacf(df1, lags=25)
plt.show()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# Chia thành các tập train, test, validation
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Hàm tạo dữ liệu cho mô hình
def create_dataset(dataset, lookback, horizon):
    X, y = [], []
    for i in range(len(dataset)-lookback-horizon+1):
        X.append(dataset[i:(i+lookback), :])
        y.append(dataset[(i+lookback):(i+lookback+horizon), 0])
    return np.array(X), np.array(y)

# %%
# Thiết lập thông số mô hình
lookback = 25
horizon = 12
n_features = 1

# %%
# Tạo dữ liệu cho mô hình
X_train, y_train = create_dataset(train_data, lookback, horizon)
X_test, y_test = create_dataset(test_data, lookback, horizon)
X_val, y_val = create_dataset(val_data, lookback, horizon)

# %%
# Xây dựng mô hình NNAR
model = Sequential()
model.add(LSTM(64, input_shape=(lookback, n_features), return_sequences=True))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(horizon))
model.compile(loss='mse', optimizer='adam')

# %%
# Huấn luyện mô hình
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), verbose=2)
# Out:
# Epoch 1/50
# 46/46 - 3s - loss: 0.0312 - val_loss: 0.0094 - 3s/epoch - 75ms/step
# Epoch 2/50
# 46/46 - 0s - loss: 0.0016 - val_loss: 0.0080 - 500ms/epoch - 11ms/step
# Epoch 3/50
# 46/46 - 1s - loss: 0.0016 - val_loss: 0.0068 - 554ms/epoch - 12ms/step
# Epoch 4/50
# 46/46 - 1s - loss: 0.0014 - val_loss: 0.0061 - 557ms/epoch - 12ms/step
# Epoch 5/50
# 46/46 - 1s - loss: 0.0014 - val_loss: 0.0078 - 541ms/epoch - 12ms/step
# Epoch 6/50
# 46/46 - 1s - loss: 0.0014 - val_loss: 0.0072 - 569ms/epoch - 12ms/step
# Epoch 7/50
# 46/46 - 1s - loss: 0.0014 - val_loss: 0.0058 - 607ms/epoch - 13ms/step
# Epoch 8/50
# 46/46 - 1s - loss: 0.0015 - val_loss: 0.0061 - 538ms/epoch - 12ms/step
# Epoch 9/50
# 46/46 - 1s - loss: 0.0013 - val_loss: 0.0074 - 552ms/epoch - 12ms/step
# Epoch 10/50
# 46/46 - 1s - loss: 0.0013 - val_loss: 0.0081 - 559ms/epoch - 12ms/step
# Epoch 11/50
# 46/46 - 1s - loss: 0.0014 - val_loss: 0.0055 - 561ms/epoch - 12ms/step
# Epoch 12/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0055 - 558ms/epoch - 12ms/step
# Epoch 13/50
# 46/46 - 1s - loss: 0.0013 - val_loss: 0.0073 - 553ms/epoch - 12ms/step
# Epoch 14/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0054 - 535ms/epoch - 12ms/step
# Epoch 15/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0052 - 566ms/epoch - 12ms/step
# Epoch 16/50
# 46/46 - 1s - loss: 0.0013 - val_loss: 0.0047 - 543ms/epoch - 12ms/step
# Epoch 17/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0052 - 571ms/epoch - 12ms/step
# Epoch 18/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0043 - 541ms/epoch - 12ms/step
# Epoch 19/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0057 - 549ms/epoch - 12ms/step
# Epoch 20/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0053 - 587ms/epoch - 13ms/step
# Epoch 21/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0041 - 553ms/epoch - 12ms/step
# Epoch 22/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0043 - 543ms/epoch - 12ms/step
# Epoch 23/50
# 46/46 - 1s - loss: 0.0010 - val_loss: 0.0038 - 545ms/epoch - 12ms/step
# Epoch 24/50
# 46/46 - 1s - loss: 0.0010 - val_loss: 0.0043 - 542ms/epoch - 12ms/step
# Epoch 25/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0038 - 531ms/epoch - 12ms/step
# Epoch 26/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0046 - 553ms/epoch - 12ms/step
# Epoch 27/50
# 46/46 - 1s - loss: 0.0010 - val_loss: 0.0041 - 541ms/epoch - 12ms/step
# Epoch 28/50
# 46/46 - 1s - loss: 0.0010 - val_loss: 0.0036 - 556ms/epoch - 12ms/step
# Epoch 29/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0042 - 553ms/epoch - 12ms/step
# Epoch 30/50
# 46/46 - 1s - loss: 9.8434e-04 - val_loss: 0.0038 - 554ms/epoch - 12ms/step
# Epoch 31/50
# 46/46 - 1s - loss: 9.9420e-04 - val_loss: 0.0033 - 555ms/epoch - 12ms/step
# Epoch 32/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0055 - 561ms/epoch - 12ms/step
# Epoch 33/50
# 46/46 - 1s - loss: 0.0010 - val_loss: 0.0036 - 592ms/epoch - 13ms/step
# Epoch 34/50
# 46/46 - 1s - loss: 9.8779e-04 - val_loss: 0.0037 - 536ms/epoch - 12ms/step
# Epoch 35/50
# 46/46 - 1s - loss: 9.5905e-04 - val_loss: 0.0040 - 572ms/epoch - 12ms/step
# Epoch 36/50
# 46/46 - 1s - loss: 9.5934e-04 - val_loss: 0.0048 - 552ms/epoch - 12ms/step
# Epoch 37/50
# 46/46 - 1s - loss: 9.6754e-04 - val_loss: 0.0040 - 547ms/epoch - 12ms/step
# Epoch 38/50
# 46/46 - 1s - loss: 9.4435e-04 - val_loss: 0.0039 - 546ms/epoch - 12ms/step
# Epoch 39/50
# 46/46 - 1s - loss: 9.6620e-04 - val_loss: 0.0048 - 568ms/epoch - 12ms/step
# Epoch 40/50
# 46/46 - 1s - loss: 9.5287e-04 - val_loss: 0.0040 - 563ms/epoch - 12ms/step
# Epoch 41/50
# 46/46 - 1s - loss: 9.3742e-04 - val_loss: 0.0031 - 531ms/epoch - 12ms/step
# Epoch 42/50
# 46/46 - 1s - loss: 9.5083e-04 - val_loss: 0.0037 - 532ms/epoch - 12ms/step
# Epoch 43/50
# 46/46 - 1s - loss: 9.2890e-04 - val_loss: 0.0034 - 531ms/epoch - 12ms/step
# Epoch 44/50
# 46/46 - 1s - loss: 9.3497e-04 - val_loss: 0.0040 - 547ms/epoch - 12ms/step
# Epoch 45/50
# 46/46 - 1s - loss: 9.4567e-04 - val_loss: 0.0033 - 547ms/epoch - 12ms/step
# Epoch 46/50
# 46/46 - 1s - loss: 9.4939e-04 - val_loss: 0.0037 - 547ms/epoch - 12ms/step
# Epoch 47/50
# 46/46 - 1s - loss: 9.3670e-04 - val_loss: 0.0038 - 547ms/epoch - 12ms/step
# Epoch 48/50
# 46/46 - 1s - loss: 9.3298e-04 - val_loss: 0.0034 - 547ms/epoch - 12ms/step
# Epoch 49/50
# 46/46 - 1s - loss: 9.1132e-04 - val_loss: 0.0030 - 547ms/epoch - 12ms/step
# Epoch 50/50
# 46/46 - 1s - loss: 9.0359e-04 - val_loss: 0.0035 - 547ms/epoch - 12ms/step

# %%
y_pred = model.predict(X_test)
y_pred_val = model.predict(X_val)
# Out:
# 13/13 [==============================] - 1s 5ms/step
# 6/6 [==============================] - 0s 6ms/step

# %%
# Scaler lại các giá trị
y_pred = scaler.inverse_transform(y_pred)
y_pred_val = scaler.inverse_transform(y_pred_val)

# %%
# Tạo một danh sách mới
y_pred = [y_pred[i][0] for i in range(len(y_pred))]
y_pred_val = [y_pred_val[i][0] for i in range(len(y_pred_val))]

# %%
# Dự đoán 30 ngày tiếp theo
num_predictions = 30
initial_input = X_val[-1]
initial_input = initial_input.reshape(1, lookback, n_features)
next30days_predictions = []
for _ in range(num_predictions):
    next_pred = model.predict(initial_input)
    next30days_predictions.append(next_pred[0])
    initial_input = np.append(initial_input[:, 1:, :], next_pred.reshape(1, horizon, n_features), axis=1)
# next30days_predictions = np.array(next30days_predictions).reshape(-1, 1)
next30days_predictions = scaler.inverse_transform(next30days_predictions)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
# Trích xuất giá trị dự đoán vào danh sách mới
next30days_predictions=[next30days_predictions[i][0] for i in range(len(next30days_predictions))]

# %%
# Tạo danh sách ngày cho trục x
dates_train = df.index[:train_size]
dates_test = df.index[train_size:train_size+test_size]
dates_val = df.index[train_size+test_size:train_size+test_size+val_size]
dates_pred = df.index[train_size+lookback+horizon-1:train_size+test_size]
dates_pred_val = df.index[train_size+test_size+lookback+horizon-1:train_size+test_size+val_size]
dates_next30days = pd.date_range(start=df.index[-1], periods=num_predictions+1)[1:]


# Vẽ biểu đồ
plt.plot(dates_train, scaler.inverse_transform(train_data), label='Train')
plt.plot(dates_test, scaler.inverse_transform(test_data), label='Test')
plt.plot(dates_val, scaler.inverse_transform(val_data), label='Validation')
plt.plot(dates_pred, y_pred, label='Predicted')
plt.plot(dates_pred_val, y_pred_val, label='Validation Predicted')
plt.plot(dates_next30days, next30days_predictions, label='Next 30 Days Predictions')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Price Predictions')
plt.legend()
plt.show()

# %% [markdown]
# <h2>2. Data ARI-Historical-Data-2015

# %%
# Import data
df = pd.read_csv('ARI-Historical-Data-2015.csv', index_col='Date', parse_dates=True)
df = df.iloc[::-1]
df1=df.reset_index()['Price']

# %%
# Kiểm tra sự tương quan một phần PAFC
plot_pacf(df1, lags=25)
plt.show()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# Chia thành các tập train, test, validation
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Hàm tạo dữ liệu cho mô hình
def create_dataset(dataset, lookback, horizon):
    X, y = [], []
    for i in range(len(dataset)-lookback-horizon+1):
        X.append(dataset[i:(i+lookback), :])
        y.append(dataset[(i+lookback):(i+lookback+horizon), 0])
    return np.array(X), np.array(y)

# %%
# Xây dựng mô hình NNAR
model = Sequential()
model.add(LSTM(64, input_shape=(lookback, n_features), return_sequences=True))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(horizon))
model.compile(loss='mse', optimizer='adam')

# %%
# Huấn luyện mô hình
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), verbose=2)
# Out:
# Epoch 1/50
# 46/46 - 4s - loss: 0.0301 - val_loss: 0.0060 - 4s/epoch - 84ms/step
# Epoch 2/50
# 46/46 - 1s - loss: 0.0015 - val_loss: 0.0064 - 755ms/epoch - 16ms/step
# Epoch 3/50
# 46/46 - 1s - loss: 0.0015 - val_loss: 0.0077 - 591ms/epoch - 13ms/step
# Epoch 4/50
# 46/46 - 1s - loss: 0.0014 - val_loss: 0.0059 - 629ms/epoch - 14ms/step
# Epoch 5/50
# 46/46 - 1s - loss: 0.0013 - val_loss: 0.0060 - 582ms/epoch - 13ms/step
# Epoch 6/50
# 46/46 - 1s - loss: 0.0014 - val_loss: 0.0058 - 584ms/epoch - 13ms/step
# Epoch 7/50
# 46/46 - 1s - loss: 0.0013 - val_loss: 0.0051 - 591ms/epoch - 13ms/step
# Epoch 8/50
# 46/46 - 1s - loss: 0.0015 - val_loss: 0.0061 - 582ms/epoch - 13ms/step
# Epoch 9/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0062 - 559ms/epoch - 12ms/step
# Epoch 10/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0055 - 578ms/epoch - 13ms/step
# Epoch 11/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0057 - 624ms/epoch - 14ms/step
# Epoch 12/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0052 - 540ms/epoch - 12ms/step
# Epoch 13/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0052 - 560ms/epoch - 12ms/step
# Epoch 14/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0043 - 666ms/epoch - 14ms/step
# Epoch 15/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0045 - 610ms/epoch - 13ms/step
# Epoch 16/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0056 - 514ms/epoch - 11ms/step
# Epoch 17/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0041 - 527ms/epoch - 11ms/step
# Epoch 18/50
# 46/46 - 0s - loss: 0.0012 - val_loss: 0.0041 - 495ms/epoch - 11ms/step
# Epoch 19/50
# 46/46 - 0s - loss: 0.0011 - val_loss: 0.0062 - 489ms/epoch - 11ms/step
# Epoch 20/50
# 46/46 - 0s - loss: 0.0011 - val_loss: 0.0041 - 481ms/epoch - 10ms/step
# Epoch 21/50
# 46/46 - 0s - loss: 0.0012 - val_loss: 0.0045 - 479ms/epoch - 10ms/step
# Epoch 22/50
# 46/46 - 0s - loss: 0.0011 - val_loss: 0.0040 - 491ms/epoch - 11ms/step
# Epoch 23/50
# 46/46 - 0s - loss: 0.0011 - val_loss: 0.0036 - 469ms/epoch - 10ms/step
# Epoch 24/50
# 46/46 - 0s - loss: 0.0010 - val_loss: 0.0056 - 452ms/epoch - 10ms/step
# Epoch 25/50
# 46/46 - 0s - loss: 0.0011 - val_loss: 0.0044 - 469ms/epoch - 10ms/step
# Epoch 26/50
# 46/46 - 0s - loss: 0.0010 - val_loss: 0.0039 - 466ms/epoch - 10ms/step
# Epoch 27/50
# 46/46 - 0s - loss: 0.0010 - val_loss: 0.0038 - 472ms/epoch - 10ms/step
# Epoch 28/50
# 46/46 - 0s - loss: 9.5576e-04 - val_loss: 0.0039 - 472ms/epoch - 10ms/step
# Epoch 29/50
# 46/46 - 0s - loss: 9.9437e-04 - val_loss: 0.0035 - 463ms/epoch - 10ms/step
# Epoch 30/50
# 46/46 - 0s - loss: 9.8832e-04 - val_loss: 0.0034 - 471ms/epoch - 10ms/step
# Epoch 31/50
# 46/46 - 0s - loss: 9.5175e-04 - val_loss: 0.0035 - 470ms/epoch - 10ms/step
# Epoch 32/50
# 46/46 - 0s - loss: 9.6912e-04 - val_loss: 0.0032 - 462ms/epoch - 10ms/step
# Epoch 33/50
# 46/46 - 1s - loss: 9.4716e-04 - val_loss: 0.0041 - 506ms/epoch - 11ms/step
# Epoch 34/50
# 46/46 - 0s - loss: 9.7801e-04 - val_loss: 0.0036 - 476ms/epoch - 10ms/step
# Epoch 35/50
# 46/46 - 1s - loss: 9.8088e-04 - val_loss: 0.0035 - 542ms/epoch - 12ms/step
# Epoch 36/50
# 46/46 - 1s - loss: 9.8017e-04 - val_loss: 0.0036 - 503ms/epoch - 11ms/step
# Epoch 37/50
# 46/46 - 0s - loss: 9.1310e-04 - val_loss: 0.0037 - 478ms/epoch - 10ms/step
# Epoch 38/50
# 46/46 - 1s - loss: 9.2894e-04 - val_loss: 0.0033 - 503ms/epoch - 11ms/step
# Epoch 39/50
# 46/46 - 0s - loss: 9.2437e-04 - val_loss: 0.0030 - 453ms/epoch - 10ms/step
# Epoch 40/50
# 46/46 - 0s - loss: 9.5511e-04 - val_loss: 0.0037 - 485ms/epoch - 11ms/step
# Epoch 41/50
# 46/46 - 0s - loss: 9.5110e-04 - val_loss: 0.0031 - 480ms/epoch - 10ms/step
# Epoch 42/50
# 46/46 - 0s - loss: 9.6443e-04 - val_loss: 0.0034 - 457ms/epoch - 10ms/step
# Epoch 43/50
# 46/46 - 0s - loss: 9.1443e-04 - val_loss: 0.0043 - 469ms/epoch - 10ms/step
# Epoch 44/50
# 46/46 - 1s - loss: 9.3288e-04 - val_loss: 0.0030 - 528ms/epoch - 11ms/step
# Epoch 45/50
# 46/46 - 1s - loss: 9.3384e-04 - val_loss: 0.0031 - 515ms/epoch - 11ms/step
# Epoch 46/50
# 46/46 - 0s - loss: 9.2734e-04 - val_loss: 0.0030 - 498ms/epoch - 11ms/step
# Epoch 47/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0033 - 500ms/epoch - 11ms/step
# Epoch 48/50
# 46/46 - 0s - loss: 8.9293e-04 - val_loss: 0.0035 - 466ms/epoch - 10ms/step
# Epoch 49/50
# 46/46 - 0s - loss: 9.0553e-04 - val_loss: 0.0029 - 498ms/epoch - 11ms/step
# Epoch 50/50
# 46/46 - 1s - loss: 9.1264e-04 - val_loss: 0.0037 - 506ms/epoch - 11ms/step

# %%
y_pred = model.predict(X_test)
y_pred_val = model.predict(X_val)
# Out:
# 13/13 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 0s 4ms/step

# %%
# Scaler lại các giá trị
y_pred = scaler.inverse_transform(y_pred)
y_pred_val = scaler.inverse_transform(y_pred_val)

# %%
# Tạo một danh sách mới
y_pred = [y_pred[i][0] for i in range(len(y_pred))]
y_pred_val = [y_pred_val[i][0] for i in range(len(y_pred_val))]

# %%
# Dự đoán 30 ngày tiếp theo
num_predictions = 30
initial_input = X_val[-1]
initial_input = initial_input.reshape(1, lookback, n_features)
next30days_predictions = []
for _ in range(num_predictions):
    next_pred = model.predict(initial_input)
    next30days_predictions.append(next_pred[0])
    initial_input = np.append(initial_input[:, 1:, :], next_pred.reshape(1, horizon, n_features), axis=1)
# next30days_predictions = np.array(next30days_predictions).reshape(-1, 1)
next30days_predictions = scaler.inverse_transform(next30days_predictions)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 493ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step

# %%
# Trích xuất giá trị dự đoán vào danh sách mới
next30days_predictions=[next30days_predictions[i][0] for i in range(len(next30days_predictions))]

# %%
# Tạo danh sách ngày cho trục x
dates_train = df.index[:train_size]
dates_test = df.index[train_size:train_size+test_size]
dates_val = df.index[train_size+test_size:train_size+test_size+val_size]
dates_pred = df.index[train_size+lookback+horizon-1:train_size+test_size]
dates_pred_val = df.index[train_size+test_size+lookback+horizon-1:train_size+test_size+val_size]
dates_next30days = pd.date_range(start=df.index[-1], periods=num_predictions+1)[1:]


# Vẽ biểu đồ
plt.plot(dates_train, scaler.inverse_transform(train_data), label='Train')
plt.plot(dates_test, scaler.inverse_transform(test_data), label='Test')
plt.plot(dates_val, scaler.inverse_transform(val_data), label='Validation')
plt.plot(dates_pred, y_pred, label='Predicted')
plt.plot(dates_pred_val, y_pred_val, label='Validation Predicted')
plt.plot(dates_next30days, next30days_predictions, label='Next 30 Days Predictions')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Price Predictions')
plt.legend()
plt.show()

# %% [markdown]
# <h2>3. Data MAA-Historical-Data-2015

# %%
# Import data
df = pd.read_csv('MAA-Historical-Data-2015.csv', index_col='Date', parse_dates=True)
df = df.iloc[::-1]
df1=df.reset_index()['Price']

# %%
# Kiểm tra sự tương quan một phần PAFC
plot_pacf(df1, lags=25)
plt.show()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# Chia thành các tập train, test, validation
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Hàm tạo dữ liệu cho mô hình
def create_dataset(dataset, lookback, horizon):
    X, y = [], []
    for i in range(len(dataset)-lookback-horizon+1):
        X.append(dataset[i:(i+lookback), :])
        y.append(dataset[(i+lookback):(i+lookback+horizon), 0])
    return np.array(X), np.array(y)

# %%
# Thiết lập thông số mô hình
lookback = 25
horizon = 12
n_features = 1

# %%
# Tạo dữ liệu cho mô hình
X_train, y_train = create_dataset(train_data, lookback, horizon)
X_test, y_test = create_dataset(test_data, lookback, horizon)
X_val, y_val = create_dataset(val_data, lookback, horizon)

# %%
# Xây dựng mô hình NNAR
model = Sequential()
model.add(LSTM(64, input_shape=(lookback, n_features), return_sequences=True))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(horizon))
model.compile(loss='mse', optimizer='adam')

# %%
# Huấn luyện mô hình
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), verbose=2)
# Out:
# Epoch 1/50
# 46/46 - 4s - loss: 0.0098 - val_loss: 0.0042 - 4s/epoch - 80ms/step
# Epoch 2/50
# 46/46 - 1s - loss: 0.0013 - val_loss: 0.0025 - 558ms/epoch - 12ms/step
# Epoch 3/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0044 - 513ms/epoch - 11ms/step
# Epoch 4/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0080 - 533ms/epoch - 12ms/step
# Epoch 5/50
# 46/46 - 1s - loss: 0.0012 - val_loss: 0.0078 - 584ms/epoch - 13ms/step
# Epoch 6/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0078 - 527ms/epoch - 11ms/step
# Epoch 7/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0089 - 536ms/epoch - 12ms/step
# Epoch 8/50
# 46/46 - 1s - loss: 0.0011 - val_loss: 0.0040 - 537ms/epoch - 12ms/step
# Epoch 9/50
# 46/46 - 1s - loss: 0.0010 - val_loss: 0.0044 - 555ms/epoch - 12ms/step
# Epoch 10/50
# 46/46 - 1s - loss: 0.0010 - val_loss: 0.0048 - 537ms/epoch - 12ms/step
# Epoch 11/50
# 46/46 - 1s - loss: 0.0010 - val_loss: 0.0068 - 540ms/epoch - 12ms/step
# Epoch 12/50
# 46/46 - 1s - loss: 9.7930e-04 - val_loss: 0.0069 - 602ms/epoch - 13ms/step
# Epoch 13/50
# 46/46 - 1s - loss: 9.9209e-04 - val_loss: 0.0046 - 545ms/epoch - 12ms/step
# Epoch 14/50
# 46/46 - 1s - loss: 0.0010 - val_loss: 0.0034 - 518ms/epoch - 11ms/step
# Epoch 15/50
# 46/46 - 1s - loss: 9.4157e-04 - val_loss: 0.0038 - 524ms/epoch - 11ms/step
# Epoch 16/50
# 46/46 - 1s - loss: 9.3294e-04 - val_loss: 0.0052 - 518ms/epoch - 11ms/step
# Epoch 17/50
# 46/46 - 1s - loss: 9.0117e-04 - val_loss: 0.0072 - 521ms/epoch - 11ms/step
# Epoch 18/50
# 46/46 - 1s - loss: 9.0682e-04 - val_loss: 0.0068 - 520ms/epoch - 11ms/step
# Epoch 19/50
# 46/46 - 1s - loss: 8.7284e-04 - val_loss: 0.0091 - 520ms/epoch - 11ms/step
# Epoch 20/50
# 46/46 - 1s - loss: 8.9092e-04 - val_loss: 0.0074 - 539ms/epoch - 12ms/step
# Epoch 21/50
# 46/46 - 1s - loss: 8.7427e-04 - val_loss: 0.0085 - 532ms/epoch - 12ms/step
# Epoch 22/50
# 46/46 - 1s - loss: 8.4867e-04 - val_loss: 0.0202 - 542ms/epoch - 12ms/step
# Epoch 23/50
# 46/46 - 1s - loss: 8.4375e-04 - val_loss: 0.0257 - 538ms/epoch - 12ms/step
# Epoch 24/50
# 46/46 - 1s - loss: 8.3562e-04 - val_loss: 0.0337 - 510ms/epoch - 11ms/step
# Epoch 25/50
# 46/46 - 1s - loss: 8.3318e-04 - val_loss: 0.0594 - 511ms/epoch - 11ms/step
# Epoch 26/50
# 46/46 - 1s - loss: 8.1257e-04 - val_loss: 0.0784 - 510ms/epoch - 11ms/step
# Epoch 27/50
# 46/46 - 1s - loss: 9.5425e-04 - val_loss: 0.0208 - 507ms/epoch - 11ms/step
# Epoch 28/50
# 46/46 - 1s - loss: 7.5131e-04 - val_loss: 0.1358 - 507ms/epoch - 11ms/step
# Epoch 29/50
# 46/46 - 1s - loss: 7.7051e-04 - val_loss: 0.0631 - 508ms/epoch - 11ms/step
# Epoch 30/50
# 46/46 - 1s - loss: 7.9597e-04 - val_loss: 0.0764 - 547ms/epoch - 12ms/step
# Epoch 31/50
# 46/46 - 1s - loss: 8.1760e-04 - val_loss: 0.1088 - 547ms/epoch - 12ms/step
# Epoch 32/50
# 46/46 - 1s - loss: 7.6092e-04 - val_loss: 0.0183 - 567ms/epoch - 12ms/step
# Epoch 33/50
# 46/46 - 1s - loss: 8.6179e-04 - val_loss: 0.0598 - 550ms/epoch - 12ms/step
# Epoch 34/50
# 46/46 - 1s - loss: 7.4120e-04 - val_loss: 0.2143 - 541ms/epoch - 12ms/step
# Epoch 35/50
# 46/46 - 1s - loss: 7.0028e-04 - val_loss: 0.2328 - 519ms/epoch - 11ms/step
# Epoch 36/50
# 46/46 - 0s - loss: 6.5276e-04 - val_loss: 0.2451 - 500ms/epoch - 11ms/step
# Epoch 37/50
# 46/46 - 0s - loss: 7.6914e-04 - val_loss: 0.0649 - 463ms/epoch - 10ms/step
# Epoch 38/50
# 46/46 - 0s - loss: 6.8900e-04 - val_loss: 0.2557 - 481ms/epoch - 10ms/step
# Epoch 39/50
# 46/46 - 0s - loss: 7.0197e-04 - val_loss: 0.3263 - 469ms/epoch - 10ms/step
# Epoch 40/50
# 46/46 - 0s - loss: 7.3225e-04 - val_loss: 0.1110 - 493ms/epoch - 11ms/step
# Epoch 41/50
# 46/46 - 1s - loss: 7.1796e-04 - val_loss: 0.3255 - 515ms/epoch - 11ms/step
# Epoch 42/50
# 46/46 - 0s - loss: 7.5175e-04 - val_loss: 0.1432 - 488ms/epoch - 11ms/step
# Epoch 43/50
# 46/46 - 0s - loss: 6.6900e-04 - val_loss: 0.1687 - 484ms/epoch - 11ms/step
# Epoch 44/50
# 46/46 - 0s - loss: 5.8667e-04 - val_loss: 0.1567 - 492ms/epoch - 11ms/step
# Epoch 45/50
# 46/46 - 1s - loss: 5.8549e-04 - val_loss: 0.0861 - 547ms/epoch - 12ms/step
# Epoch 46/50
# 46/46 - 1s - loss: 5.9769e-04 - val_loss: 0.1698 - 509ms/epoch - 11ms/step
# Epoch 47/50
# 46/46 - 1s - loss: 5.6235e-04 - val_loss: 0.1535 - 508ms/epoch - 11ms/step
# Epoch 48/50
# 46/46 - 1s - loss: 5.8628e-04 - val_loss: 0.2074 - 507ms/epoch - 11ms/step
# Epoch 49/50
# 46/46 - 1s - loss: 5.7255e-04 - val_loss: 0.1444 - 508ms/epoch - 11ms/step
# Epoch 50/50
# 46/46 - 1s - loss: 5.2991e-04 - val_loss: 0.1755 - 512ms/epoch - 11ms/step

# %%
y_pred = model.predict(X_test)
y_pred_val = model.predict(X_val)
# Out:
# 13/13 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# Scaler lại các giá trị
y_pred = scaler.inverse_transform(y_pred)
y_pred_val = scaler.inverse_transform(y_pred_val)

# %%
# Tạo một danh sách mới
y_pred = [y_pred[i][0] for i in range(len(y_pred))]
y_pred_val = [y_pred_val[i][0] for i in range(len(y_pred_val))]

# %%
# Dự đoán 30 ngày tiếp theo
num_predictions = 30
initial_input = X_val[-1]
initial_input = initial_input.reshape(1, lookback, n_features)
next30days_predictions = []
for _ in range(num_predictions):
    next_pred = model.predict(initial_input)
    next30days_predictions.append(next_pred[0])
    initial_input = np.append(initial_input[:, 1:, :], next_pred.reshape(1, horizon, n_features), axis=1)
# next30days_predictions = np.array(next30days_predictions).reshape(-1, 1)
next30days_predictions = scaler.inverse_transform(next30days_predictions)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step

# %%
# Trích xuất giá trị dự đoán vào danh sách mới
next30days_predictions=[next30days_predictions[i][0] for i in range(len(next30days_predictions))]

# %%
# Tạo danh sách ngày cho trục x
dates_train = df.index[:train_size]
dates_test = df.index[train_size:train_size+test_size]
dates_val = df.index[train_size+test_size:train_size+test_size+val_size]
dates_pred = df.index[train_size+lookback+horizon-1:train_size+test_size]
dates_pred_val = df.index[train_size+test_size+lookback+horizon-1:train_size+test_size+val_size]
dates_next30days = pd.date_range(start=df.index[-1], periods=num_predictions+1)[1:]


# Vẽ biểu đồ
plt.plot(dates_train, scaler.inverse_transform(train_data), label='Train')
plt.plot(dates_test, scaler.inverse_transform(test_data), label='Test')
plt.plot(dates_val, scaler.inverse_transform(val_data), label='Validation')
plt.plot(dates_pred, y_pred, label='Predicted')
plt.plot(dates_pred_val, y_pred_val, label='Validation Predicted')
plt.plot(dates_next30days, next30days_predictions, label='Next 30 Days Predictions')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Price Predictions')
plt.legend()
plt.show()
